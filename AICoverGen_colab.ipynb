# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/varaslaw/AISingersCoverGen/blob/main/AICoverGen_colab.ipynb)

# %% [markdown]
# # AISingersCoverGen WebUI
#
# This notebook targets the refreshed Python 3.10–3.12 + Gradio 5.23.x stack. Click `Runtime` → `Run all` and wait for the final cell to print the public Gradio URL before opening it.

# %%
#@title Clone repository
# !git clone https://github.com/varaslaw/AISingersCoverGen.git
# %cd AISingersCoverGen

# %%
#@title Install requirements
# !python -m pip install -U pip wheel
# !python -m pip install -q -r requirements.txt
# !sudo apt update
# !sudo apt install -y sox ffmpeg

# %%
#@title Download MDXNet Vocal Separation and Hubert Base Models
# !python src/download_models.py

# %%
#@title Run WebUI
# !python src/webui-ru.py --share
